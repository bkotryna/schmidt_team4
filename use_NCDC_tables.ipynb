# %%
# get the giant df that was made from pdfs

import pandas as pd

giant_df = pd.read_csv('data/20200502_20200817_pdfs.csv')
giant_df.reset_index(drop=True)
giant_df.drop(giant_df.columns[0], axis=1, inplace=True)
giant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3735 entries, 0 to 3734
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             3735 non-null   object
#  1   total_confirmed   3735 non-null   object
#  2   new_confirmed     3735 non-null   object
#  3   total_discharged  3735 non-null   object
#  4   new_dicharged     3735 non-null   int64
#  5   total_deaths      3735 non-null   object
#  6   new_deaths        3735 non-null   object
#  7   total_active      3735 non-null   object
#  8   date              3735 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 262.7+ KB

# %%
display(giant_df.index.nunique())

giant_df.columns

# %%
date_list = giant_df['date'].unique().tolist()

display(len(date_list))

# sort the list alphabetically - this just puts 2020-07-07 in its place
date_list = sorted(date_list)

date_list

# %%
# most entries are strings => convert into numeric
sub_df = giant_df

for i in range(1,8):
    print(i)
    sub_df.iloc[:,i] = pd.to_numeric(sub_df.iloc[:,i])
    
sub_df.info()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             500 non-null    object
#  1   total_confirmed   500 non-null    int64
#  2   new_confirmed     500 non-null    int64
#  3   total_discharged  500 non-null    int64
#  4   new_dicharged     500 non-null    int64
#  5   total_deaths      500 non-null    int64
#  6   new_deaths        500 non-null    int64
#  7   total_active      500 non-null    int64
#  8   date              500 non-null    object
# dtypes: int64(7), object(2)
# memory usage: 35.3+ KB

# %%
giant_df.iloc[1412,:] = 'Akwa Ibom', 48, 3, 17, 3, 2, 0, 29, '2020-06-13'
giant_df.iloc[1412,:]
# Out:
# state                Akwa Ibom
# total_confirmed             48
# new_confirmed                3
# total_discharged            17
# new_dicharged                3
# total_deaths                 2
# new_deaths                   0
# total_active                29
# date                2020-06-13
# Name: 1412, dtype: object

# %%
# ongoing issue
# a gift that keeps on giving


# most entries are strings => convert into numeric
sub_df = giant_df

for i in range(1,8):
    print(i)
    sub_df.iloc[:,i] = pd.to_numeric(sub_df.iloc[:,i])
    
sub_df.info()

# %%
# split into separate df's by date
# create a list of df's, ordered by date

groups = giant_df.groupby('date')

df_list = []
for date in date_list:
    df = groups.get_group(date)
    df_list.append(df)
print(len(df_list))

df_list[2].info()

df_list[2]['total_confirmed'] = pd.to_numeric(df_list[2]['total_confirmed'])
test_df = df_list[2]
test_df.info()
# Out:
# 103
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 70 to 104
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             35 non-null     object
#  1   total_confirmed   35 non-null     object
#  2   new_confirmed     35 non-null     object
#  3   total_discharged  35 non-null     object
#  4   new_dicharged     35 non-null     int64
#  5   total_deaths      35 non-null     object
#  6   new_deaths        35 non-null     object
#  7   total_active      35 non-null     object
#  8   date              35 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 2.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 70 to 104
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             35 non-null     object
#  1   total_confirmed   35 non-null     int64
#  2   new_confirmed     35 non-null     object
#  3   total_discharged  35 non-null     object
#  4   new_dicharged     35 non-null     int64
#  5   total_deaths      35 non-null     object
#  6   new_deaths        35 non-null     object
#  7   total_active      35 non-null     object
#  8   date              35 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 2.7+ KB
# <ipython-input-50-2f1b3f5a5d77>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_list[2]['total_confirmed'] = pd.to_numeric(df_list[2]['total_confirmed'])

# %%
test_df1 = df_list[1]
test_df2 = df_list[2]
test_df3 = df_list[3]

# %%
# most entries are strings => convert into numeric

test_df_list = [test_df1, test_df2, test_df3]
for test_df in test_df_list:
    for i in range(1,8):
        # print(i)
        test_df.iloc[:,i] = pd.to_numeric(test_df.iloc[:,i])
    print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 35 to 69
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             35 non-null     object
#  1   total_confirmed   35 non-null     int64
#  2   new_confirmed     35 non-null     int64
#  3   total_discharged  35 non-null     int64
#  4   new_dicharged     35 non-null     int64
#  5   total_deaths      35 non-null     int64
#  6   new_deaths        35 non-null     int64
#  7   total_active      35 non-null     int64
#  8   date              35 non-null     object
# dtypes: int64(7), object(2)
# memory usage: 2.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 70 to 104
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             35 non-null     object
#  1   total_confirmed   35 non-null     int64
#  2   new_confirmed     35 non-null     int64
#  3   total_discharged  35 non-null     int64
#  4   new_dicharged     35 non-null     int64
#  5   total_deaths      35 non-null     int64
#  6   new_deaths        35 non-null     int64
#  7   total_active      35 non-null     int64
#  8   date              35 non-null     object
# dtypes: int64(7), object(2)
# memory usage: 2.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 105 to 139
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             35 non-null     object
#  1   total_confirmed   35 non-null     int64
#  2   new_confirmed     35 non-null     int64
#  3   total_discharged  35 non-null     int64
#  4   new_dicharged     35 non-null     int64
#  5   total_deaths      35 non-null     int64
#  6   new_deaths        35 non-null     int64
#  7   total_active      35 non-null     int64
#  8   date              35 non-null     object
# dtypes: int64(7), object(2)
# memory usage: 2.7+ KB
# None

# %%
# just a basic bar-plot, cases vs state name
# df_3 = df_list[2]
# df_3[['state','total_confirmed']].plot(kind='bar', title ="total_confirmed cases per state", figsize=(15, 10), legend=True, fontsize=12)


ax = test_df3.plot.bar(x='state', y='total_confirmed', rot=0)
# Out:
# <img src="data:image/png;base64,..." width="NaN">

# %% [markdown]
# ## Let's get Nigerian data to scroll

# %%
import numpy as np
import matplotlib.pyplot as plt

# enables interactive plot in jupyter
# %matplotlib notebook


# define your x and y arrays to be plotted
# add (x,y) tuples to a list
# when you press left / right arrows, you'll move through that list

plots = []
for test_df in test_df_list:
    x = test_df['state']
    y = test_df['total_confirmed']
    data_tuple = (x,y)
    plots.append(data_tuple)


# now the real code :)
# ie setting up scrolling

curr_pos = 0

def key_event(e):
    global curr_pos

    if e.key == "right":
        curr_pos = curr_pos + 1
    elif e.key == "left":
        curr_pos = curr_pos - 1
    else:
        return
    curr_pos = curr_pos % len(plots)

    # clear the current axes, apparently
    ax.cla()
    
    # your plot
    # using data from the list, choosing positions according to 'curr_pos', which changes as you press left/right arrows
    ax.bar(plots[curr_pos][0], plots[curr_pos][1])
    # make labels vertical
    plt.xticks(rotation=90)
    
    fig.canvas.draw()

    
# need to look into what exactly each one of these does
fig = plt.figure()
fig.canvas.mpl_connect('key_press_event', key_event)
ax = fig.add_subplot(111)



# I think this is just the starting plot
# if you comment it out, the plot is blank until you press arrow key
ax.bar(plots[curr_pos][0], plots[curr_pos][1])
# make labels vertical
plt.xticks(rotation=90)

# show plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Scrollable matplotlib plots - from stack overflow
#
# https://stackoverflow.com/questions/18390461/scroll-backwards-and-forwards-through-matplotlib-plots/18391039

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook



# define your x and y arrays to be plotted
t = np.linspace(start=0, stop=2*np.pi, num=100)
y1 = np.cos(t)
y2 = np.sin(t)
y3 = np.tan(t)
plots = [(t,y1), (t,y2), (t,y3)]

# now the real code :) 
curr_pos = 0

def key_event(e):
    global curr_pos

    if e.key == "right":
        curr_pos = curr_pos + 1
    elif e.key == "left":
        curr_pos = curr_pos - 1
    else:
        return
    curr_pos = curr_pos % len(plots)

    ax.cla()
    ax.plot(plots[curr_pos][0], plots[curr_pos][1])
    fig.canvas.draw()

fig = plt.figure()
fig.canvas.mpl_connect('key_press_event', key_event)
ax = fig.add_subplot(111)
ax.plot(t,y1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
