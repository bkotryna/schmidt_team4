# %% [markdown]
# ## To do
#
# ### state names
#
# - get a full list of desired state names
# - filter giant_df to state names that aren't in the list
# - manually check & fix those entries by replacing rows by index
#
#
# ### geo plotting with scrolling
#
# - fuse geo plotting with scrolling
# - just for some basic data in the first instance
# - will need to use geo_env

# %%
# get the giant df that was made from pdfs

import pandas as pd

giant_df = pd.read_csv('data/20200502_20200817_pdfs.csv')

# clean the index
giant_df.reset_index(drop=True)
giant_df.drop(giant_df.columns[0], axis=1, inplace=True)


# manual fixing of some rows
giant_df.iloc[1412,:] = 'Akwa Ibom', 48, 3, 17, 3, 2, 0, 29, '2020-06-13'
giant_df.iloc[2957,:] = 'FCT', 3560, 35, 1077, 13, 41, 0, 2442, '2020-07-28'
giant_df.iloc[2984,:] = 'Sokoto', 154, 0, 137, 90, 16, 0, 1, '2020-07-28'

giant_df.iloc[1494,:] = 'Lagos', 7461, 142, 1302, 165, 107, 25, 6052, '2020-06-16'
giant_df.iloc[2436,:] = 'Lagos', 12711, 128, 1935, 19, 175, 2, 10601, '2020-07-14'
giant_df.iloc[3550,:] = 'Lagos', 16369, 113, 14457, 1325, 201, 0, 1711, '2020-08-14'
giant_df.iloc[3587,:] = 'Lagos', 16456, 87, 14467, 10, 201, 0, 1788, '2020-08-15'
giant_df.loc[2771, 'new_deaths'] = 15

# %%
# manual tracing & fixing

# giant_df[giant_df['date']=='2020-07-23']['state']
# giant_df.iloc[3587,:] = 'Lagos', 16456, 87, 14467, 10, 201, 0, 1788, '2020-08-15'
# giant_df.loc[2771, 'new_deaths'] = 15
# giant_df.loc[2771, 'new_deaths']
# Out:
# 15

# %%
# convert date from string to date format
giant_df['date']= giant_df['date'].astype('datetime64[ns]')

# check information
giant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3735 entries, 0 to 3734
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             3735 non-null   object
#  1   total_confirmed   3735 non-null   object
#  2   new_confirmed     3735 non-null   object
#  3   total_discharged  3735 non-null   object
#  4   new_dicharged     3735 non-null   int64
#  5   total_deaths      3735 non-null   object
#  6   new_deaths        3735 non-null   object
#  7   total_active      3735 non-null   object
#  8   date              3735 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 262.7+ KB

# %%
# inspect
giant_df.head()
# Out:
#    state total_confirmed new_confirmed total_discharged  new_dicharged  \
# 0  Lagos            1068            62              247             22
# 1   Kano             313             2                7              7
# 2    FCT             266            52               36              0
# 3  Gombe              96             4                0              0
# 4  Borno              75             6                0              0
#
#   total_deaths new_deaths total_active       date
# 0           30          2          791 2020-05-02
# 1            6          3          300 2020-05-02
# 2            3          0          227 2020-05-02
# 3            0          0           96 2020-05-02
# 4           11          5           64 2020-05-02

# %%
# inspect

display(giant_df.index.nunique())
giant_df.columns
# Out:
# 3735
# Index(['state', 'total_confirmed', 'new_confirmed', 'total_discharged',
#        'new_dicharged', 'total_deaths', 'new_deaths', 'total_active', 'date'],
#       dtype='object')

# %% [markdown]
# ### Leave digits-only in an entry

# %%
# most entries are strings => convert into numeric

import numpy as np

for i in [1,2,3,5,6,7]:
    # print(i)
    giant_df.iloc[:,i] = giant_df.iloc[:,i].apply(lambda x: ''.join(ch for ch in str(x) if ch.isdigit()))
    giant_df.iloc[:,i] = pd.to_numeric(giant_df.iloc[:,i])
    # sub_df.iloc[:,i] = sub_df.iloc[:,i].apply(lambda x: int(x) if x else 'missing')
    
giant_df.info()
# why are total confirmed and new_confirmed floats ??
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3735 entries, 0 to 3734
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             3735 non-null   object
#  1   total_confirmed   3735 non-null   int64
#  2   new_confirmed     3735 non-null   int64
#  3   total_discharged  3735 non-null   int64
#  4   new_dicharged     3735 non-null   int64
#  5   total_deaths      3735 non-null   int64
#  6   new_deaths        3735 non-null   int64
#  7   total_active      3735 non-null   int64
#  8   date              3735 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 262.7+ KB

# %% [markdown]
# ### Fix state names to match geopandas notebook

# %%
# full list of desired state names, as it is in geopandas noteebook

states = ['Abia', 'Adamawa', 'Akwa Ibom', 'Anambra', 'Bauchi', 'Bayelsa', 'Benue',
       'Borno', 'Cross River', 'Delta', 'Ebonyi', 'Edo', 'Ekiti', 'Enugu',
       'Federal Capital Territory', 'Gombe', 'Imo', 'Jigawa', 'Kaduna', 'Kano',
       'Katsina', 'Kebbi', 'Kogi', 'Kwara', 'Lagos', 'Nasarawa', 'Niger',
       'Ogun', 'Ondo', 'Osun', 'Oyo', 'Plateau', 'Rivers', 'Sokoto', 'Taraba',
       'Yobe', 'Zamfara']
states
# Out:
# ['Abia',
#  'Adamawa',
#  'Akwa Ibom',
#  'Anambra',
#  'Bauchi',
#  'Bayelsa',
#  'Benue',
#  'Borno',
#  'Cross River',
#  'Delta',
#  'Ebonyi',
#  'Edo',
#  'Ekiti',
#  'Enugu',
#  'Federal Capital Territory',
#  'Gombe',
#  'Imo',
#  'Jigawa',
#  'Kaduna',
#  'Kano',
#  'Katsina',
#  'Kebbi',
#  'Kogi',
#  'Kwara',
#  'Lagos',
#  'Nasarawa',
#  'Niger',
#  'Ogun',
#  'Ondo',
#  'Osun',
#  'Oyo',
#  'Plateau',
#  'Rivers',
#  'Sokoto',
#  'Taraba',
#  'Yobe',
#  'Zamfara']

# %%
giant_states = sorted(giant_df['state'].unique().tolist())
giant_states

giant_df['state'] = giant_df['state'].apply(lambda x: 'Federal Capital Territory' if x == 'FCT' else x)
giant_df['state'] = giant_df['state'].apply(lambda x: 'Akwa Ibom' if x.startswith('Akwa') else x)
# giant_df['state'] = giant_df['state'].apply(lambda x: 'Cross River' if x == 'River' else x)
giant_df['state'] = giant_df['state'].apply(lambda x: 'Cross River' if x == 'Cross Rivers' else x)
giant_df = giant_df[giant_df['state'] != 'Ibom']

giant_states = sorted(giant_df['state'].unique().tolist())

# check item-by-item if the lists match
for item in giant_states:
    if item in states:
        print(item, ' in both lists')
    else:
        print(item, ' not in geo states list')
        
# check the whole list
giant_states == states

# => woohoo, state names fixed!
# Out:
# Abia  in both lists
# Adamawa  in both lists
# Akwa Ibom  in both lists
# Anambra  in both lists
# Bauchi  in both lists
# Bayelsa  in both lists
# Benue  in both lists
# Borno  in both lists
# Cross River  in both lists
# Delta  in both lists
# Ebonyi  in both lists
# Edo  in both lists
# Ekiti  in both lists
# Enugu  in both lists
# Federal Capital Territory  in both lists
# Gombe  in both lists
# Imo  in both lists
# Jigawa  in both lists
# Kaduna  in both lists
# Kano  in both lists
# Katsina  in both lists
# Kebbi  in both lists
# Kogi  in both lists
# Kwara  in both lists
# Lagos  in both lists
# Nasarawa  in both lists
# Niger  in both lists
# Ogun  in both lists
# Ondo  in both lists
# Osun  in both lists
# Oyo  in both lists
# Plateau  in both lists
# River  not in geo states list
# Rivers  in both lists
# Sokoto  in both lists
# Taraba  in both lists
# Yobe  in both lists
# Zamfara  in both lists
# False

# %%
## fixing state names

## issue no1

# row_index_list = giant_df.index[giant_df['state'] == 'River'].tolist()
# row_index_list
# row = giant_df.iloc[row_index_list[0],:]
# row

## issue no2
# row_index_list = giant_df.index[giant_df['state'] == 'Ibom'].tolist()
# row_index_list
# for index in row_index_list:
#     # print(index)
#     # display(giant_df.iloc[index,:])
#     date = giant_df.iloc[index,8]
#     print(date)
#     # whole_date = giant_df[(giant_df['date'] == date)]
#     # display(whole_date)
#     ibom = giant_df[(giant_df['date'] == date) & (giant_df['state'] == 'Ibom')].iloc[0,1:].tolist()
#     akwa = giant_df[(giant_df['date'] == date) & (giant_df['state'] == 'Akwa Ibom')].iloc[0,1:].tolist()
#     display(ibom == akwa)

# %% [markdown]
# ### Make sub-df's by date

# %%
# get a list of dates - useful for iterating through them later

date_list = giant_df['date'].unique().tolist()
display(len(date_list))

# sort the list alphabetically - this just puts 2020-07-07 in its place
date_list = sorted(date_list)
# display(date_list)

# rev_date_list = sorted(date_list, reverse=True)
# print(rev_date_list)
# Out:
# 103

# %%
# split into separate df's by date
# create a list of df's, ordered by date
# within each df, order rows by state alphabetically

groups = giant_df.groupby('date')

df_list = []
for date in date_list:
    df = groups.get_group(date)
    
    # within each df, order rows alphabetically by state
    df.sort_values(by=['state'], inplace=True)
    
    df_list.append(df)
print(len(df_list))
# Out:
# 103
# <ipython-input-53-9e366e664dcf>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by=['state'], inplace=True)

# %% [markdown]
# ## Let's get Nigerian data to scroll

# %%
# test date conversions
# pd.to_datetime(date_list[curr_pos]).date()

# %%
# hacky way to hide toolbars in the interactive matplotlib plots
# https://stackoverflow.com/questions/41928387/jupyter-interactive-matplotlib-hide-the-toolbar-of-the-interactive-view

# this is ridiculous - it worked once, but then keeps throwing "invalid syntax" error....
# tight_layout saved me anyway though, now the toolbars don't overlap with other elements, so all okay

# %%html
<style>
.output_wrapper button.btn.btn-default,
.output_wrapper .ui-dialog-titlebar {
  display: none;
}
</style>
# Out:
#   File "<ipython-input-18-23ae8a4e9138>", line 8
#     <style>
#     ^
# SyntaxError: invalid syntax

# %%
# plot total cases per state, scroll over time

import numpy as np
import matplotlib.pyplot as plt

# enables interactive plot in jupyter
# %matplotlib notebook

# define your x and y arrays to be plotted
# add (x,y) tuples to a list
# when you scroll up/down, you'll move through that list

plots = []
for one_df in df_list:
    x = one_df['state']
    y = one_df['total_confirmed']
    data_tuple = (x,y)
    plots.append(data_tuple)


# now the real code :)
# ie setting up scrolling

curr_pos = 0

def key_event(e):
    global curr_pos

    #if e.key == "right":
    if e.button == 'up':
        curr_pos = curr_pos + 1
        
    #elif e.key == "left":
    elif e.button == 'down':
        curr_pos = curr_pos - 1
    else:
        return
    curr_pos = curr_pos % len(plots)

    # clear the current axes, apparently
    ax.cla()
    
    # your plot
    # using data from the list, choosing positions according to 'curr_pos', which changes as you press left/right arrows
    ax.bar(plots[curr_pos][0], plots[curr_pos][1])
    # make labels vertical
    plt.xticks(rotation=90)
    ax.set_title(f'Total cases\n{pd.to_datetime(date_list[curr_pos]).date()}')
    # fixes space around the plot
    plt.tight_layout()
    
    fig.canvas.draw()

    
# need to look into what exactly each one of these does
fig = plt.figure()


# attempt to remove toolbar
#plt.rcParams['toolbar'] = 'toolmanager'
#fig.canvas.manager.toolmanager.add_tool('home')


#fig.canvas.mpl_connect('key_press_event', key_event)
fig.canvas.mpl_connect('scroll_event', key_event)
ax = fig.add_subplot(111)


# initial plot
# using data from the list, choosing positions according to 'curr_pos', which changes as you press left/right arrows
ax.bar(plots[curr_pos][0], plots[curr_pos][1])
# make labels vertical
plt.xticks(rotation=90)
ax.set_title(f'Total cases\n{pd.to_datetime(date_list[curr_pos]).date()}')
# fixes space around the plot
plt.tight_layout()

# show plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plot new cases per state, scroll over time

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker

# enables interactive plot in jupyter
# %matplotlib notebook

# define your x and y arrays to be plotted
# add (x,y) tuples to a list
# when you scroll up/down, you'll move through that list

plots = []
for one_df in df_list:
    x = one_df['state']
    y = one_df['new_confirmed']
    data_tuple = (x,y)
    plots.append(data_tuple)


# now the real code :)
# ie setting up scrolling

curr_pos = 0

def key_event(e):
    global curr_pos

    #if e.key == "right":
    if e.button == 'up':
        curr_pos = curr_pos + 1
        
    #elif e.key == "left":
    elif e.button == 'down':
        curr_pos = curr_pos - 1
    else:
        return
    curr_pos = curr_pos % len(plots)

    # clear the current axes, apparently
    ax.cla()
    
    # your plot
    # using data from the list, choosing positions according to 'curr_pos', which changes as you press left/right arrows
    ax.bar(plots[curr_pos][0], plots[curr_pos][1])
    # make labels vertical
    plt.xticks(rotation=90)
    ax.set_title(f'New daily cases\n{pd.to_datetime(date_list[curr_pos]).date()}')
    
    # fixes space around the plot
    plt.tight_layout()
    
    fig.canvas.draw()

    
# need to look into what exactly each one of these does
fig = plt.figure()


# attempt to remove toolbar
#plt.rcParams['toolbar'] = 'toolmanager'
#fig.canvas.manager.toolmanager.add_tool('home')


#fig.canvas.mpl_connect('key_press_event', key_event)
fig.canvas.mpl_connect('scroll_event', key_event)
ax = fig.add_subplot(111)



# initial plot
# using data from the list, choosing positions according to 'curr_pos', which changes as you press left/right arrows
ax.bar(plots[curr_pos][0], plots[curr_pos][1])
# make labels vertical
plt.xticks(rotation=90)
ax.set_title(f'New daily cases\n{pd.to_datetime(date_list[curr_pos]).date()}')

# fixes space around the plot
plt.tight_layout()

# fixes space around the plot
plt.tight_layout()

# show plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# plot new deaths per state, scroll over time

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# enables interactive plot in jupyter
# %matplotlib notebook

# define your x and y arrays to be plotted
# add (x,y) tuples to a list
# when you scroll up/down, you'll move through that list

plots = []
for one_df in df_list:
    x = one_df['state']
    y = one_df['new_deaths']
    data_tuple = (x,y)
    plots.append(data_tuple)


# now the real code :)
# ie setting up scrolling

curr_pos = 0 # set this to -1 if you start with no plot showing

def key_event(e):
    global curr_pos

    #if e.key == "right":
    if e.button == 'up':
        curr_pos = curr_pos + 1
        
    #elif e.key == "left":
    elif e.button == 'down':
        curr_pos = curr_pos - 1
    else:
        return
    curr_pos = curr_pos % len(plots)

    # clear the current axes, apparently
    ax.cla()
    
    # your plot
    # using data from the list, choosing positions according to 'curr_pos', which changes as you press left/right arrows
    ax.bar(plots[curr_pos][0], plots[curr_pos][1])
    # make labels vertical
    plt.xticks(rotation=90)
    ax.set_title(f'New daily deaths\n{pd.to_datetime(date_list[curr_pos]).date()}')
    
    # play with y-numbering
    #plt.locator_params(axis="y", integer=True, tight=True)
    if max(plots[curr_pos][1]) <= 10:
        tick_spacing = 1
    elif max(plots[curr_pos][1]) <= 20:
        tick_spacing = 2
    elif max(plots[curr_pos][1]) <= 50:
        tick_spacing = 5
    else:
        tick_spacing = 10
    ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

    # fixes space around the plot
    plt.tight_layout()
    fig.canvas.draw()

    
# need to look into what exactly each one of these does
fig = plt.figure()


# attempt to remove toolbar
#plt.rcParams['toolbar'] = 'toolmanager'
#fig.canvas.manager.toolmanager.add_tool('home')


#fig.canvas.mpl_connect('key_press_event', key_event)
fig.canvas.mpl_connect('scroll_event', key_event)
ax = fig.add_subplot(111)



# initial plot
# using data from the list, choosing positions according to 'curr_pos', which changes as you press left/right arrows
ax.bar(plots[curr_pos][0], plots[curr_pos][1])
# make labels vertical
plt.xticks(rotation=90)
ax.set_title(f'New daily deaths\n{pd.to_datetime(date_list[curr_pos]).date()}')

# play with y-numbering
# plt.locator_params(axis="y", integer=True, tight=True)

tick_spacing = 1
ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))


# fixes space around the plot
plt.tight_layout()

# show plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
## tinker with y-axis ticks / axis range - work in progress

# tick_spacing = 10
# ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
# y_top = ((max(plots[curr_pos][1])) // 10 + 1) * 10
# plt.ylim((0, y_top))


# even mor random stuff for this
# ax.yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
# ax.yaxis.set_minor_locator(ticker.MaxNLocator(integer=True))
# ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:.0f}'))
# ax.minorticks_off()

# %% [markdown]
# ## Source: Scrollable matplotlib plots - from stack overflow
#
# https://stackoverflow.com/questions/18390461/scroll-backwards-and-forwards-through-matplotlib-plots/18391039

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook



# define your x and y arrays to be plotted
t = np.linspace(start=0, stop=2*np.pi, num=100)
y1 = np.cos(t)
y2 = np.sin(t)
y3 = np.tan(t)
plots = [(t,y1), (t,y2), (t,y3)]

# now the real code :) 
curr_pos = 0

def key_event(e):
    global curr_pos

    if e.key == "right":
        curr_pos = curr_pos + 1
    elif e.key == "left":
        curr_pos = curr_pos - 1
    else:
        return
    curr_pos = curr_pos % len(plots)

    ax.cla()
    ax.plot(plots[curr_pos][0], plots[curr_pos][1])
    fig.canvas.draw()

fig = plt.figure()
fig.canvas.mpl_connect('key_press_event', key_event)
ax = fig.add_subplot(111)
ax.plot(t,y1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
